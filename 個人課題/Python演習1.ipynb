# %% [markdown]
# # Python演習課題1

# %% [markdown]
# ## 課題1

# %% [markdown]
# ### 問1
#
# 文字列"datascience"の文字を逆に（末尾から先頭に向かって）並べた文字列を出力してください

# %%
print("ecnicsatad")

# %% [markdown]
# ### 問2
#
# 「ヘエルスシトンニキア」という文字列の1,3,5,7,9文字目を取り出して連結した文字列を出力してください

# %%
# 元の文字列を定義
original_word = "ヘエルスシトンニキア"

# 結果を格納する変数を初期化
result = ""

# 取り出したい文字の位置
# Pythonでは文字列のインデックスは0から始まる
# 1文字目 → インデックス0、2文字目 → インデックス1、...
positions = [0, 2, 4, 6, 8]  # 1,3,5,7,9文字目のインデックス

# 各位置の文字を取り出して結果に追加
for pos in positions:
    result += original_word[pos]

# 結果を出力
print(f"元の文字列: {original_word}")
print(f"取り出した文字: {result}")

# %% [markdown]
# ### 問3
#
# 「ヘルシンキ」＋「エストニア」の文字を先頭から交互に連結して文字列「ヘエルスシトンニキア」を出力してください

# %%
word1 = "ヘルシンキ"
word2 = "エストニア"



# 文字列を1文字ずつ交互に連結
result = ""

for c1, c2 in zip(word1, word2):
   result += c1 + c2 

print(f"連結した文字列: {result}")

# %% [markdown]
# ### 問4
#
# "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成してください

# %%
sentence = "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan."

# 文字数をカウント
char_count = len(sentence)
print(f"文字数: {char_count}")  

# 単語数をカウント
words = sentence.split()  # スペースで分割して単語のリストを作成
word_count = len(words)
print(f"単語数: {word_count}") 

#　各アルファベットの文字数を先頭から出現順に並べたリストを作成
char_counts = [len(word) for word in words]
print(f"各単語の文字数リスト: {char_counts}")

# 各単語とその文字数を表示
for word, count in zip(words, char_counts):
    print(f"単語: {word}, 文字数: {count}")
# Out:
# 文字数: 84
# 単語数: 12
# 各単語の文字数リスト: [9, 9, 5, 2, 3, 11, 6, 2, 8, 3, 3, 12]
# 単語: Character, 文字数: 9
# 単語: education, 文字数: 9
# 単語: based, 文字数: 5
# 単語: on, 文字数: 2
# 単語: the, 文字数: 3
# 単語: fundamental, 文字数: 11
# 単語: spirit, 文字数: 6
# 単語: of, 文字数: 2
# 単語: Buddhism, 文字数: 8
# 単語: and, 文字数: 3
# 単語: the, 文字数: 3
# 単語: Shiguzeigan., 文字数: 12

# %% [markdown]
# ### 問5
#
# "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."という文を単語に分解し，1, 2, 5, 6, 8, 9, 16番目の単語の先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）を格納した辞書を作成してください

# %%
# Out:
# is no of th th su It
